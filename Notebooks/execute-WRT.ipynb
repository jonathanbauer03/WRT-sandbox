# %% [markdown]
# # Welcome to the WRT-sandbox

# %% [markdown]
# How to run this Jupyter-Notebook:
# - To run a cell, click on it and press the play sign in the toolbar in the top left of your screen or press "Shift"+"Enter".
# - The graphs and images generated in this notebook can be downloaded by clicking on the folder sign on the left and then again in the smaller folder sign to reach the /home/jovyan directory. From there go to /Data->/Graphics-WRT and right-click on the desired file to choose download.

# %% [markdown]
# ### Start your own routing:
# 1. Set the two map markers to your desired locations (startpoint: green, endpoint: red). For meaningful results, place them inside the green box.
# 2. Select a start time. Note that there is no weather data outside this timeframe so adjust the start time to the length of your route.
# 3. Press "start routing".  <span style="color:red">The routing may take a little while.</span> Note: If you start a new routing the data of your last route will be deleted.
# 4. You can look at route data by pressing on the route markers.
# 5. If you run "display_route_graphs.py", you can visualize the results for the estimation of the fule consumption. If you run "display_routing_steps.py" you can track the routing segments that have been analysed for the individual routing step.
# 6. Press "new route" if you want to calculate another route.

# %%
# %run /home/jovyan/Programmes/interactive_WRT.py

# %% [markdown]
# ### What happens in the Background:
# 1. When you press "start routing", the programm will write your start and end points and the start time to the config file, a file that contains all configuration for your planned route.
# 2. The Weather Routing Tool (WRT) will read this file and calculate a route considering weather and bathymetry data. The route points will then be written to a new file min_time_route.json.
# 3. The route is displayed by the blue map markers.
# 4. You can find the log file for your routing in the /Data folder (the path is explained above).
# 5. For an in-depth explanation on the function of the WRT, you can read the [ReadMe](https://github.com/52North/WeatherRoutingTool/blob/main/README.md).

# %% [markdown]
# ### You can go through graphs on your routing by moving the slider.

# %%
# %run /home/jovyan/Programmes/display_route_graphs.py

# %% [markdown]
# ### You can go through the routing steps by moving the slider.

# %% [markdown]
# In the Images, you can see the possible routes considered by the tool for your route. Every new image shows the next route segments considered for every route using the [Isofuel Algorithm](https://github.com/52North/WeatherRoutingTool/blob/main/README.md#isofuel-algorithm).

# %%
# %run /home/jovyan/Programmes/display_routing_steps.py
